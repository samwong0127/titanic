# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('./'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# ./prediction1.csv
# ./prediction2.csv
# ./README.md
# ./titanic.ipynb
# ./.ipynb_checkpoints\titanic-checkpoint.ipynb
# ./data\gender_submission.csv
# ./data\test.csv
# ./data\train.csv

# %% [markdown]
# #### Read CSV

# %%
#df_train_o = pd.read_csv('/kaggle/titanic/data/train.csv')
#df_test_o = pd.read_csv('/kaggle/titanic/data/test.csv')
df_train_o = pd.read_csv('./data/train.csv')
df_test_o = pd.read_csv('./data/test.csv')

# %%
df_train_o
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df_test_o
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 0      male  34.5      0      0              330911    7.8292   NaN        Q
# 1    female  47.0      1      0              363272    7.0000   NaN        S
# 2      male  62.0      0      0              240276    9.6875   NaN        Q
# 3      male  27.0      0      0              315154    8.6625   NaN        S
# 4    female  22.0      1      1             3101298   12.2875   NaN        S
# ..      ...   ...    ...    ...                 ...       ...   ...      ...
# 413    male   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  female  39.0      0      0            PC 17758  108.9000  C105        C
# 415    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416    male   NaN      0      0              359309    8.0500   NaN        S
# 417    male   NaN      1      1                2668   22.3583   NaN        C
#
# [418 rows x 11 columns]

# %% [markdown]
# #### Embarked: Port of Embarkation

# %% [markdown]
# #### Get the number of NULL in train set

# %%
df_train_o.isnull().sum(axis = 0)
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df_test_o.isnull().sum(axis = 0)
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %% [markdown]
# ### Drop PassengerId, Name (irrelvant), Cabin (too many NULL)

# %%
df_train = df_train_o.drop(columns=['PassengerId', 'Cabin','Name'])
df_train
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch            Ticket     Fare  \
# 0           0       3    male  22.0      1      0         A/5 21171   7.2500
# 1           1       1  female  38.0      1      0          PC 17599  71.2833
# 2           1       3  female  26.0      0      0  STON/O2. 3101282   7.9250
# 3           1       1  female  35.0      1      0            113803  53.1000
# 4           0       3    male  35.0      0      0            373450   8.0500
# ..        ...     ...     ...   ...    ...    ...               ...      ...
# 886         0       2    male  27.0      0      0            211536  13.0000
# 887         1       1  female  19.0      0      0            112053  30.0000
# 888         0       3  female   NaN      1      2        W./C. 6607  23.4500
# 889         1       1    male  26.0      0      0            111369  30.0000
# 890         0       3    male  32.0      0      0            370376   7.7500
#
#     Embarked
# 0          S
# 1          C
# 2          S
# 3          S
# 4          S
# ..       ...
# 886        S
# 887        S
# 888        S
# 889        C
# 890        Q
#
# [891 rows x 9 columns]

# %%
df_train.isnull().sum(axis = 0)
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Embarked      2
# dtype: int64

# %%
df_train.mode()
# Out:
#    Survived  Pclass   Sex   Age  SibSp  Parch    Ticket  Fare Embarked
# 0       0.0     3.0  male  24.0    0.0    0.0      1601  8.05        S
# 1       NaN     NaN   NaN   NaN    NaN    NaN    347082   NaN      NaN
# 2       NaN     NaN   NaN   NaN    NaN    NaN  CA. 2343   NaN      NaN

# %%
df_train.mean()
# Out:
# Survived     0.383838
# Pclass       2.308642
# Age         29.699118
# SibSp        0.523008
# Parch        0.381594
# Fare        32.204208
# dtype: float64

# %%
df_train.median()
# Out:
# Survived     0.0000
# Pclass       3.0000
# Age         28.0000
# SibSp        0.0000
# Parch        0.0000
# Fare        14.4542
# dtype: float64

# %% [markdown]
# #### Do so for test.csv

# %%
df_test = df_test_o.drop(columns=['PassengerId', 'Cabin','Name'])
df_test
# Out:
#      Pclass     Sex   Age  SibSp  Parch              Ticket      Fare Embarked
# 0         3    male  34.5      0      0              330911    7.8292        Q
# 1         3  female  47.0      1      0              363272    7.0000        S
# 2         2    male  62.0      0      0              240276    9.6875        Q
# 3         3    male  27.0      0      0              315154    8.6625        S
# 4         3  female  22.0      1      1             3101298   12.2875        S
# ..      ...     ...   ...    ...    ...                 ...       ...      ...
# 413       3    male   NaN      0      0           A.5. 3236    8.0500        S
# 414       1  female  39.0      0      0            PC 17758  108.9000        C
# 415       3    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500        S
# 416       3    male   NaN      0      0              359309    8.0500        S
# 417       3    male   NaN      1      1                2668   22.3583        C
#
# [418 rows x 8 columns]

# %% [markdown]
# ### Feature engineering
#
# #### NULL value -> (removal, replace by mean/median/-1)
# #### cat -> num (frequency, ordinal)

# %%
from sklearn import preprocessing

# %%
values = {"Embarked": 'S', "Age": 28}
df_train2 = df_train.fillna(value=values)

# %%
df_train2
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch            Ticket     Fare  \
# 0           0       3    male  22.0      1      0         A/5 21171   7.2500
# 1           1       1  female  38.0      1      0          PC 17599  71.2833
# 2           1       3  female  26.0      0      0  STON/O2. 3101282   7.9250
# 3           1       1  female  35.0      1      0            113803  53.1000
# 4           0       3    male  35.0      0      0            373450   8.0500
# ..        ...     ...     ...   ...    ...    ...               ...      ...
# 886         0       2    male  27.0      0      0            211536  13.0000
# 887         1       1  female  19.0      0      0            112053  30.0000
# 888         0       3  female  28.0      1      2        W./C. 6607  23.4500
# 889         1       1    male  26.0      0      0            111369  30.0000
# 890         0       3    male  32.0      0      0            370376   7.7500
#
#     Embarked
# 0          S
# 1          C
# 2          S
# 3          S
# 4          S
# ..       ...
# 886        S
# 887        S
# 888        S
# 889        C
# 890        Q
#
# [891 rows x 9 columns]

# %%
df_train2.isnull().sum(axis=0)
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Embarked    0
# dtype: int64

# %% [markdown]
# #### Do so for test.csv

# %%
df_test2 = df_test.fillna(value=values)
df_test2.isnull().sum(axis=0)
# Out:
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        1
# Embarked    0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

matrix = df_train2.corr().round(2)
sns.heatmap(matrix, annot=True)
plt.show()
# categorical features excluded

# %%
import matplotlib.pyplot as plt
def printHeatmap(df):
    matrix = df.corr().round(2)
    fig, ax = plt.subplots(figsize=(10,10))   
    sns.heatmap(matrix, annot=True, ax=ax)
    plt.show()

# %% [markdown]
# #### Extract title from name and extract isMs

# %%
# Reference: https://www.kaggle.com/code/sergioortiz/titanic-competition-data-exploration-1/notebook
def multipleReplace(text, wordDic):
    for key in wordDic:
        if text.lower()==key.lower():
            text=wordDic[key]
            break
    return text

def normaliseTitle(title):
    wordDic = {
    'Mlle': 'Miss',
    'Ms': 'Mrs',
    'Mrs':'Mrs',
    'Master':'Master',
    'Mme': 'Mrs',
    'Lady': 'Nobility',
    'Countess': 'Nobility',
    'Capt': 'Army',
    'Col': 'Army',
    'Dona': 'Other',
    'Don': 'Other',
    'Dr': 'Other',
    'Major': 'Army',
    'Rev': 'Other',
    'Sir': 'Other',
    'Jonkheer': 'Other',
    }     
    title=multipleReplace(title,wordDic)
    return title

def extractTitleFromName(name):
    pos_point=name.find('.')
    if pos_point == -1: return ""
    wordList=name[0:pos_point].split(" ")
    if len(wordList)<=0: return ""
    title=wordList[len(wordList)-1]
    normalisedTitle=normaliseTitle(title)
    return normalisedTitle

# Get a list with different titles
titleList=(df_train_o['Name'].apply(lambda x: extractTitleFromName(x)))
df_train2['title'] = titleList

# %%
df_train2['IsMs']=(df_train2["title"]).apply(lambda x: 1 if x=='Mrs' or x == 'Miss' else 0)

# %%
df_train2
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch            Ticket     Fare  \
# 0           0       3    male  22.0      1      0         A/5 21171   7.2500
# 1           1       1  female  38.0      1      0          PC 17599  71.2833
# 2           1       3  female  26.0      0      0  STON/O2. 3101282   7.9250
# 3           1       1  female  35.0      1      0            113803  53.1000
# 4           0       3    male  35.0      0      0            373450   8.0500
# ..        ...     ...     ...   ...    ...    ...               ...      ...
# 886         0       2    male  27.0      0      0            211536  13.0000
# 887         1       1  female  19.0      0      0            112053  30.0000
# 888         0       3  female  28.0      1      2        W./C. 6607  23.4500
# 889         1       1    male  26.0      0      0            111369  30.0000
# 890         0       3    male  32.0      0      0            370376   7.7500
#
#     Embarked  title  IsMs
# 0          S     Mr     0
# 1          C    Mrs     1
# 2          S   Miss     1
# 3          S    Mrs     1
# 4          S     Mr     0
# ..       ...    ...   ...
# 886        S  Other     0
# 887        S   Miss     1
# 888        S   Miss     1
# 889        C     Mr     0
# 890        Q     Mr     0
#
# [891 rows x 11 columns]

# %% [markdown]
# #### Do so for test.csv

# %%
titleList=(df_test_o['Name'].apply(lambda x: extractTitleFromName(x)))
df_test2['title'] = titleList
df_test2['IsMs']=(df_test2["title"]).apply(lambda x: 1 if x=='Mrs' or x == 'Miss' else 0)
df_test2
# Out:
#      Pclass     Sex   Age  SibSp  Parch              Ticket      Fare  \
# 0         3    male  34.5      0      0              330911    7.8292
# 1         3  female  47.0      1      0              363272    7.0000
# 2         2    male  62.0      0      0              240276    9.6875
# 3         3    male  27.0      0      0              315154    8.6625
# 4         3  female  22.0      1      1             3101298   12.2875
# ..      ...     ...   ...    ...    ...                 ...       ...
# 413       3    male  28.0      0      0           A.5. 3236    8.0500
# 414       1  female  39.0      0      0            PC 17758  108.9000
# 415       3    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500
# 416       3    male  28.0      0      0              359309    8.0500
# 417       3    male  28.0      1      1                2668   22.3583
#
#     Embarked   title  IsMs
# 0          Q      Mr     0
# 1          S     Mrs     1
# 2          Q      Mr     0
# 3          S      Mr     0
# 4          S     Mrs     1
# ..       ...     ...   ...
# 413        S      Mr     0
# 414        C   Other     0
# 415        S      Mr     0
# 416        S      Mr     0
# 417        C  Master     0
#
# [418 rows x 10 columns]

# %%
enc = preprocessing.OrdinalEncoder()

# %%
df_train2[["Sex", "Embarked", "title"]] = enc.fit_transform(df_train2[["Sex", "Embarked", "title"]])

# %%
df_train3 = df_train2

# %%
printHeatmap(df_train3)

# %%
df_test2[["Sex", "Embarked", "title"]] = enc.transform(df_test2[["Sex", "Embarked", "title"]])

# %% [markdown]
# #### SibSp has lowest correlation with Survived
# #### Sex and Fare, Pclass are higher
# #### Pclass has high relationship with Fare

# %% [markdown]
# ### Add more features

# %%
df_train3['IsAlone']=(df_train3["SibSp"]+df_train3["Parch"]).apply(lambda x: 0 if x>0 else 1)
df_train3['FamilySize']=df_train3["SibSp"]+df_train3["Parch"]+1
df_train3['hasSibSp']=(df_train3["SibSp"]).apply(lambda x: 1 if x>0 else 0)
df_train3['hasParch']=(df_train3["Parch"]).apply(lambda x: 1 if x>0 else 0)

# %%
df_train3
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch            Ticket     Fare  \
# 0           0       3  1.0  22.0      1      0         A/5 21171   7.2500
# 1           1       1  0.0  38.0      1      0          PC 17599  71.2833
# 2           1       3  0.0  26.0      0      0  STON/O2. 3101282   7.9250
# 3           1       1  0.0  35.0      1      0            113803  53.1000
# 4           0       3  1.0  35.0      0      0            373450   8.0500
# ..        ...     ...  ...   ...    ...    ...               ...      ...
# 886         0       2  1.0  27.0      0      0            211536  13.0000
# 887         1       1  0.0  19.0      0      0            112053  30.0000
# 888         0       3  0.0  28.0      1      2        W./C. 6607  23.4500
# 889         1       1  1.0  26.0      0      0            111369  30.0000
# 890         0       3  1.0  32.0      0      0            370376   7.7500
#
#      Embarked  title  IsMs  IsAlone  FamilySize  hasSibSp  hasParch
# 0         2.0    3.0     0        0           2         1         0
# 1         0.0    4.0     1        0           2         1         0
# 2         2.0    2.0     1        1           1         0         0
# 3         2.0    4.0     1        0           2         1         0
# 4         2.0    3.0     0        1           1         0         0
# ..        ...    ...   ...      ...         ...       ...       ...
# 886       2.0    6.0     0        1           1         0         0
# 887       2.0    2.0     1        1           1         0         0
# 888       2.0    2.0     1        0           4         1         1
# 889       0.0    3.0     0        1           1         0         0
# 890       1.0    3.0     0        1           1         0         0
#
# [891 rows x 15 columns]

# %%
printHeatmap(df_train3)

# %%
df_train4 = df_train3.drop(columns=['Ticket'])
df_train4.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked  title  IsMs  \
# 0         0       3  1.0  22.0      1      0   7.2500       2.0    3.0     0
# 1         1       1  0.0  38.0      1      0  71.2833       0.0    4.0     1
# 2         1       3  0.0  26.0      0      0   7.9250       2.0    2.0     1
# 3         1       1  0.0  35.0      1      0  53.1000       2.0    4.0     1
# 4         0       3  1.0  35.0      0      0   8.0500       2.0    3.0     0
#
#    IsAlone  FamilySize  hasSibSp  hasParch
# 0        0           2         1         0
# 1        0           2         1         0
# 2        1           1         0         0
# 3        0           2         1         0
# 4        1           1         0         0

# %% [markdown]
# #### Do so for test.csv

# %%
df_test3 = df_test2

# %%
df_test3['IsAlone']=(df_test3["SibSp"]+df_test3["Parch"]).apply(lambda x: 0 if x>0 else 1)
df_test3['FamilySize']=df_test3["SibSp"]+df_test3["Parch"]+1
df_test3['hasSibSp']=(df_test3["SibSp"]).apply(lambda x: 1 if x>0 else 0)
df_test3['hasParch']=(df_test3["Parch"]).apply(lambda x: 1 if x>0 else 0)

# %%
df_test4 = df_test3.drop(columns=['Ticket'])
df_test4.head()
# Out:
#    Pclass  Sex   Age  SibSp  Parch     Fare  Embarked  title  IsMs  IsAlone  \
# 0       3  1.0  34.5      0      0   7.8292       1.0    3.0     0        1
# 1       3  0.0  47.0      1      0   7.0000       2.0    4.0     1        0
# 2       2  1.0  62.0      0      0   9.6875       1.0    3.0     0        1
# 3       3  1.0  27.0      0      0   8.6625       2.0    3.0     0        1
# 4       3  0.0  22.0      1      1  12.2875       2.0    4.0     1        0
#
#    FamilySize  hasSibSp  hasParch
# 0           1         0         0
# 1           2         1         0
# 2           1         0         0
# 3           1         0         0
# 4           3         1         1

# %%
sns.distplot(df_train4['Fare'])

# %%
sns.distplot(df_train4['Age'])

# %%
sns.distplot(df_train4['FamilySize'])

# %%
df_train4[df_train4['Age'] < 4]
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch      Fare  Embarked  title  \
# 7           0       3  1.0  2.00      3      1   21.0750       2.0    1.0
# 16          0       3  1.0  2.00      4      1   29.1250       1.0    1.0
# 43          1       2  0.0  3.00      1      2   41.5792       0.0    2.0
# 78          1       2  1.0  0.83      0      2   29.0000       2.0    1.0
# 119         0       3  0.0  2.00      4      2   31.2750       2.0    2.0
# 164         0       3  1.0  1.00      4      1   39.6875       2.0    1.0
# 172         1       3  0.0  1.00      1      1   11.1333       2.0    2.0
# 183         1       2  1.0  1.00      2      1   39.0000       2.0    1.0
# 193         1       2  1.0  3.00      1      1   26.0000       2.0    1.0
# 205         0       3  0.0  2.00      0      1   10.4625       2.0    2.0
# 261         1       3  1.0  3.00      4      2   31.3875       2.0    1.0
# 297         0       1  0.0  2.00      1      2  151.5500       2.0    2.0
# 305         1       1  1.0  0.92      1      2  151.5500       2.0    1.0
# 340         1       2  1.0  2.00      1      1   26.0000       2.0    1.0
# 348         1       3  1.0  3.00      1      1   15.9000       2.0    1.0
# 374         0       3  0.0  3.00      3      1   21.0750       2.0    2.0
# 381         1       3  0.0  1.00      0      2   15.7417       0.0    2.0
# 386         0       3  1.0  1.00      5      2   46.9000       2.0    1.0
# 407         1       2  1.0  3.00      1      1   18.7500       2.0    1.0
# 469         1       3  0.0  0.75      2      1   19.2583       0.0    2.0
# 479         1       3  0.0  2.00      0      1   12.2875       2.0    2.0
# 530         1       2  0.0  2.00      1      1   26.0000       2.0    2.0
# 642         0       3  0.0  2.00      3      2   27.9000       2.0    2.0
# 644         1       3  0.0  0.75      2      1   19.2583       0.0    2.0
# 755         1       2  1.0  0.67      1      1   14.5000       2.0    1.0
# 788         1       3  1.0  1.00      1      2   20.5750       2.0    1.0
# 803         1       3  1.0  0.42      0      1    8.5167       0.0    1.0
# 824         0       3  1.0  2.00      4      1   39.6875       2.0    1.0
# 827         1       2  1.0  1.00      0      2   37.0042       0.0    1.0
# 831         1       2  1.0  0.83      1      1   18.7500       2.0    1.0
#
#      IsMs  IsAlone  FamilySize  hasSibSp  hasParch
# 7       0        0           5         1         1
# 16      0        0           6         1         1
# 43      1        0           4         1         1
# 78      0        0           3         0         1
# 119     1        0           7         1         1
# 164     0        0           6         1         1
# 172     1        0           3         1         1
# 183     0        0           4         1         1
# 193     0        0           3         1         1
# 205     1        0           2         0         1
# 261     0        0           7         1         1
# 297     1        0           4         1         1
# 305     0        0           4         1         1
# 340     0        0           3         1         1
# 348     0        0           3         1         1
# 374     1        0           5         1         1
# 381     1        0           3         0         1
# 386     0        0           8         1         1
# 407     0        0           3         1         1
# 469     1        0           4         1         1
# 479     1        0           2         0         1
# 530     1        0           3         1         1
# 642     1        0           6         1         1
# 644     1        0           4         1         1
# 755     0        0           3         1         1
# 788     0        0           4         1         1
# 803     0        0           2         0         1
# 824     0        0           6         1         1
# 827     0        0           3         0         1
# 831     0        0           3         1         1

# %% [markdown]
# ### Remove outliers in Fare and FamilySize

# %%
df_train5 = df_train4[df_train4['Fare'] < 200]
df_train5 = df_train5[df_train5['FamilySize'] < 7]
df_train5
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked  title  \
# 0           0       3  1.0  22.0      1      0   7.2500       2.0    3.0
# 1           1       1  0.0  38.0      1      0  71.2833       0.0    4.0
# 2           1       3  0.0  26.0      0      0   7.9250       2.0    2.0
# 3           1       1  0.0  35.0      1      0  53.1000       2.0    4.0
# 4           0       3  1.0  35.0      0      0   8.0500       2.0    3.0
# ..        ...     ...  ...   ...    ...    ...      ...       ...    ...
# 886         0       2  1.0  27.0      0      0  13.0000       2.0    6.0
# 887         1       1  0.0  19.0      0      0  30.0000       2.0    2.0
# 888         0       3  0.0  28.0      1      2  23.4500       2.0    2.0
# 889         1       1  1.0  26.0      0      0  30.0000       0.0    3.0
# 890         0       3  1.0  32.0      0      0   7.7500       1.0    3.0
#
#      IsMs  IsAlone  FamilySize  hasSibSp  hasParch
# 0       0        0           2         1         0
# 1       1        0           2         1         0
# 2       1        1           1         0         0
# 3       1        0           2         1         0
# 4       0        1           1         0         0
# ..    ...      ...         ...       ...       ...
# 886     0        1           1         0         0
# 887     1        1           1         0         0
# 888     1        0           4         1         1
# 889     0        1           1         0         0
# 890     0        1           1         0         0
#
# [846 rows x 14 columns]

# %%
from sklearn.preprocessing import RobustScaler, StandardScaler, MinMaxScaler, Normalizer

# %%
robustScaler = RobustScaler().fit(df_train5.drop(columns=['Survived']))
arr_temp = robustScaler.transform(df_train5.drop(columns=['Survived']))
arr_temp
# Out:
# array([[ 0.        ,  0.        , -0.47058824, ...,  1.        ,
#          1.        ,  0.        ],
#        [-2.        , -1.        ,  0.78431373, ...,  1.        ,
#          1.        ,  0.        ],
#        [ 0.        , -1.        , -0.15686275, ...,  0.        ,
#          0.        ,  0.        ],
#        ...,
#        [ 0.        , -1.        ,  0.        , ...,  3.        ,
#          1.        ,  1.        ],
#        [-2.        ,  0.        , -0.15686275, ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.        ,  0.        ,  0.31372549, ...,  0.        ,
#          0.        ,  0.        ]])

# %%
minmaxScaler = MinMaxScaler().fit(df_train5.drop(columns=['Survived']))
arr_train_scaled = minmaxScaler.transform(df_train5.drop(columns=['Survived']))
arr_train_scaled
# Out:
# array([[1.        , 1.        , 0.27117366, ..., 0.2       , 1.        ,
#         0.        ],
#        [0.        , 0.        , 0.4722292 , ..., 0.2       , 1.        ,
#         0.        ],
#        [1.        , 0.        , 0.32143755, ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [1.        , 0.        , 0.34656949, ..., 0.6       , 1.        ,
#         1.        ],
#        [0.        , 1.        , 0.32143755, ..., 0.        , 0.        ,
#         0.        ],
#        [1.        , 1.        , 0.39683338, ..., 0.        , 0.        ,
#         0.        ]])

# %% [markdown]
# #### Scale test data

# %%
arr_test_scaled = minmaxScaler.transform(df_test4)
arr_test_scaled

# %% [markdown]
# ## Model training

# %% [markdown]
# #### Select features

# %%
features_selected = ['Pclass', 'Sex', 'Fare', 'Embarked', 'IsMs', 'IsAlone', 'FamilySize', 'hasSibSp' , 'hasParch']
features_not_selected = ["Ticket"]

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC


from sklearn.model_selection import cross_val_score

# %%
dtc = DecisionTreeClassifier(random_state=12)

rfc = RandomForestClassifier(random_state=12)

nn = MLPClassifier(solver='lbfgs', alpha=1,hidden_layer_sizes=(15,), random_state=1)

logR = LogisticRegression(max_iter=30000)

svc = SVC(C=4)

kernel = 1.0 * RBF(1.0)
gpc = GaussianProcessClassifier(kernel=kernel, random_state=0)

# %%
y = df_train5['Survived']
X = arr_train_scaled

# %%
print(X.shape)
print(y.shape)
# Out:
# (846, 13)
# (846,)

# %% [markdown]
# #### Decision Tree Classifier

# %%
cross_val_score(dtc, X, y, cv=4)
# Out:
# array([0.76233184, 0.77578475, 0.77130045, 0.79279279])

# %% [markdown]
# #### Random Forest Classifier

# %%
cross_val_score(rfc, X, y, cv=4)# added familysize, isAlone
# Out:
# array([0.77130045, 0.82959641, 0.83408072, 0.86486486])

# %%
cross_val_score(rfc, X, y, cv=4)# added isAlone only
# Out:
# array([0.76233184, 0.83856502, 0.81165919, 0.85135135])

# %%
cross_val_score(rfc, X, y, cv=4) # added familysize, isAlone, hasSibSp, hasParch
# Out:
# array([0.78026906, 0.82959641, 0.8206278 , 0.83333333])

# %%
cross_val_score(rfc, X, y, cv=4) # added isAlone, hasSibSp, hasParch (removed SibSp, Parch)
# Out:
# array([0.77578475, 0.83408072, 0.80717489, 0.84684685])

# %%
cross_val_score(rfc, X, y, cv=4) # ['Pclass', 'Sex', 'Parch', 'Fare', 'Embarked', 'IsMs', 'IsAlone', 'hasSibSp', 'hasParch']
# Out:
# array([0.70852018, 0.82959641, 0.8161435 , 0.80630631])

# %%
cross_val_score(rfc, X, y, cv=4) # ['Pclass', 'Sex', 'Fare', 'Embarked', 'IsMs', 'IsAlone']
# Out:
# array([0.71300448, 0.82959641, 0.82959641, 0.80630631])

# %%
cross_val_score(rfc, X, y, cv=4) # ['Pclass', 'Sex', 'Fare', 'Embarked', 'IsMs', 'IsAlone', 'FamilySize']
# Out:
# array([0.71300448, 0.82959641, 0.82959641, 0.80630631])

# %%
# Pclass, Sex, Age, SibSp, Parch, Fare, Embarked, title, IsMs, IsAlone, FamilySize, hasSibSp, hasParch
# MinMax scaled
cross_val_score(rfc, X, y, cv=4)
# Out:
# array([0.75943396, 0.82075472, 0.82464455, 0.79146919])

# %% [markdown]
# #### Logistic Regression

# %%
cross_val_score(logR, X, y, cv=4)
# Out:
# array([0.76681614, 0.78475336, 0.77130045, 0.78828829])

# %% [markdown]
# #### Neural Network

# %%
cross_val_score(nn, X, y, cv=4)
# Out:
# F:\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:549: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# F:\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:549: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# F:\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:549: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# F:\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:549: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# array([0.70852018, 0.77130045, 0.78026906, 0.78378378])

# %%
df_test3[df_test3['Fare'].isnull()]
# Out:
#      Pclass  Sex   Age  SibSp  Parch Ticket  Fare  Embarked  title  IsMs  \
# 152       3  1.0  60.5      0      0   3701   NaN       2.0    3.0     0
#
#      IsAlone  FamilySize  hasSibSp  hasParch
# 152        1           1         0         0

# %%
x = df_test3.loc[df_test3['Pclass']==3]
print(f'mean\n: {x.mean()}\nmedian\n: {x.median()}\nmode\n: {x.mode()}\n')
# Out:
# mean: Pclass         3.000000
# Sex            0.669725
# Age           25.339817
# SibSp          0.463303
# Parch          0.417431
# Fare          12.459678
# Embarked       1.490826
# title          2.733945
# IsMs           0.330275
# IsAlone        0.678899
# FamilySize     1.880734
# hasSibSp       0.266055
# hasParch       0.206422
# dtype: float64
# median: Pclass         3.0000
# Sex            1.0000
# Age           28.0000
# SibSp          0.0000
# Parch          0.0000
# Fare           7.8958
# Embarked       2.0000
# title          3.0000
# IsMs           0.0000
# IsAlone        1.0000
# FamilySize     1.0000
# hasSibSp       0.0000
# hasParch       0.0000
# dtype: float64
# mode:    Pclass  Sex   Age  SibSp  Parch    Ticket  Fare  Embarked  title  IsMs  \
# 0       3  1.0  28.0      0      0  CA. 2343  7.75       2.0    3.0     0
#
#    IsAlone  FamilySize  hasSibSp  hasParch
# 0        1           1         0         0

# %%
df_test3 = df_test3.fillna({"Fare": 7.89})

# %%
rfc.fit(X, y)
y_pred = rfc.predict(df_test3[features_selected])

# %%
logR.fit(X, y)
y_pred = logR.predict(df_test3[features_selected])

# %%
df_test_o
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 0      male  34.5      0      0              330911    7.8292   NaN        Q
# 1    female  47.0      1      0              363272    7.0000   NaN        S
# 2      male  62.0      0      0              240276    9.6875   NaN        Q
# 3      male  27.0      0      0              315154    8.6625   NaN        S
# 4    female  22.0      1      1             3101298   12.2875   NaN        S
# ..      ...   ...    ...    ...                 ...       ...   ...      ...
# 413    male   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  female  39.0      0      0            PC 17758  108.9000  C105        C
# 415    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416    male   NaN      0      0              359309    8.0500   NaN        S
# 417    male   NaN      1      1                2668   22.3583   NaN        C
#
# [418 rows x 11 columns]

# %%
df_test3
# Out:
#      Pclass  Sex   Age  SibSp  Parch              Ticket      Fare  Embarked  \
# 0         3  1.0  34.5      0      0              330911    7.8292       1.0
# 1         3  0.0  47.0      1      0              363272    7.0000       2.0
# 2         2  1.0  62.0      0      0              240276    9.6875       1.0
# 3         3  1.0  27.0      0      0              315154    8.6625       2.0
# 4         3  0.0  22.0      1      1             3101298   12.2875       2.0
# ..      ...  ...   ...    ...    ...                 ...       ...       ...
# 413       3  1.0  28.0      0      0           A.5. 3236    8.0500       2.0
# 414       1  0.0  39.0      0      0            PC 17758  108.9000       0.0
# 415       3  1.0  38.5      0      0  SOTON/O.Q. 3101262    7.2500       2.0
# 416       3  1.0  28.0      0      0              359309    8.0500       2.0
# 417       3  1.0  28.0      1      1                2668   22.3583       0.0
#
#      title  IsMs  IsAlone  FamilySize  hasSibSp  hasParch
# 0      3.0     0        1           1         0         0
# 1      4.0     1        0           2         1         0
# 2      3.0     0        1           1         0         0
# 3      3.0     0        1           1         0         0
# 4      4.0     1        0           3         1         1
# ..     ...   ...      ...         ...       ...       ...
# 413    3.0     0        1           1         0         0
# 414    6.0     0        1           1         0         0
# 415    3.0     0        1           1         0         0
# 416    3.0     0        1           1         0         0
# 417    1.0     0        0           3         1         1
#
# [418 rows x 14 columns]

# %%
def predictor(model, X, y, test_data):
    model.fit(X, y)
    y_pred = model.predict(test_data)
    return y_pred
    
def csvTransformer(df_test_o, y_pred, filename):
    df = pd.DataFrame()
    df['PassengerId'] = df_test_o['PassengerId']
    df['Survived'] = y_pred
    
    df.to_csv(filename, index=False)
    print('Saved')
    return

y_pred = predictor(rfc, X, y, arr_test_scaled)
csvTransformer(df_test_o, y_pred, 'prediction4.csv')
# Out:
# Saved

# %% [markdown]
# ### Drop SibSp

# %%
X2 = X.drop(columns=['Ticket','SibSp'])
cross_val_score(rfc, X2, y, cv=4)
# Out:
# array([0.75784753, 0.83408072, 0.82959641, 0.80630631])

# %% [markdown]
# But accuracy drops

# %% [markdown]
# ### Try in both:
# SibSp and Parch: Yes/No
#
# ### May try in ordinal encoding:
# Embarked, Pclass: (1, 50, 100)
# Sex: (1, 100)
# Ticket: removal

# %% [markdown]
# ### Try frequency encoding

# %%
df_train
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch            Ticket     Fare  \
# 0           0       3    male  22.0      1      0         A/5 21171   7.2500
# 1           1       1  female  38.0      1      0          PC 17599  71.2833
# 2           1       3  female  26.0      0      0  STON/O2. 3101282   7.9250
# 3           1       1  female  35.0      1      0            113803  53.1000
# 4           0       3    male  35.0      0      0            373450   8.0500
# ..        ...     ...     ...   ...    ...    ...               ...      ...
# 886         0       2    male  27.0      0      0            211536  13.0000
# 887         1       1  female  19.0      0      0            112053  30.0000
# 888         0       3  female   NaN      1      2        W./C. 6607  23.4500
# 889         1       1    male  26.0      0      0            111369  30.0000
# 890         0       3    male  32.0      0      0            370376   7.7500
#
#     Embarked
# 0          S
# 1          C
# 2          S
# 3          S
# 4          S
# ..       ...
# 886        S
# 887        S
# 888        S
# 889        C
# 890        Q
#
# [891 rows x 9 columns]

# %%
for x in df_train.columns:
    print(df_train[x].value_counts())
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64
# male      577
# female    314
# Name: Sex, dtype: int64
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 28.00    25
#          ..
# 36.50     1
# 55.50     1
# 0.92      1
# 23.50     1
# 74.00     1
# Name: Age, Length: 88, dtype: int64
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: SibSp, dtype: int64
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: Parch, dtype: int64
# 347082      7
# CA. 2343    7
# 1601        7
# 3101295     6
# CA 2144     6
#            ..
# 9234        1
# 19988       1
# 2693        1
# PC 17612    1
# 370376      1
# Name: Ticket, Length: 681, dtype: int64
# 8.0500     43
# 13.0000    42
# 7.8958     38
# 7.7500     34
# 26.0000    31
#            ..
# 35.0000     1
# 28.5000     1
# 6.2375      1
# 14.0000     1
# 10.5167     1
# Name: Fare, Length: 248, dtype: int64
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64
